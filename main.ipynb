# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
df = pd.read_csv('./archive/smoking_driking_dataset_Ver01.csv')
df.head()
# Out:
#     sex  age  height  weight  waistline  sight_left  sight_right  hear_left  \
# 0  Male   35     170      75       90.0         1.0          1.0        1.0
# 1  Male   30     180      80       89.0         0.9          1.2        1.0
# 2  Male   40     165      75       91.0         1.2          1.5        1.0
# 3  Male   50     175      80       91.0         1.5          1.2        1.0
# 4  Male   50     165      60       80.0         1.0          1.2        1.0
#
#    hear_right    SBP  ...  LDL_chole  triglyceride  hemoglobin  urine_protein  \
# 0         1.0  120.0  ...      126.0          92.0        17.1            1.0
# 1         1.0  130.0  ...      148.0         121.0        15.8            1.0
# 2         1.0  120.0  ...       74.0         104.0        15.8            1.0
# 3         1.0  145.0  ...      104.0         106.0        17.6            1.0
# 4         1.0  138.0  ...      117.0         104.0        13.8            1.0
#
# ...

# %%
def age_cat(age):
    if age >= 20 and age <= 35:
        return 'AGE: 20-35'
    elif age >= 36 and age <= 45:
        return 'AGE: 36-45'
    elif age >= 46 and age <= 60:
        return 'AGE: 46-60'
    else:
        return 'AGE: 61-85'

def height_cat(h):
    if h >= 130 and h <= 155:
        return 'Height: 130-155'
    elif h >= 156 and h <= 160:
        return 'Height: 156-160'
    elif h >= 161 and h <= 170:
        return 'Height: 161-170'
    else:
        return 'Height: 171-190'
    
def weight_cat(d):
    if d >= 25 and d <= 55:
        return 'Weight: 25-55'
    elif d >= 56 and d <= 60:
        return 'Weight: 56-60'
    elif d >= 61 and d <= 70:
        return 'Weight: 61-70'
    else:
        return 'Weight: 71-140'   

def waistline_cat(d):
    if d >= 8 and d <= 75:
        return 'Waistline: 8-75'
    elif d >= 76 and d <= 81:
        return 'Waistline: 76-81'
    elif d >= 82 and d <= 88:
        return 'Waistline: 82-88'
    else:
        return 'Waistline: >88'   
    
def sightr_cat(d):
    if d >= 0.1 and d <= 0.7:
        return 'Sight right: 0.1-0.7'
    elif d >= 0.71 and d <= 1.0:
        return 'Sight right: 0.71-1.0'
    elif d >= 1.1 and d <= 1.2:
        return 'Sight right: 1.1-1.2'
    else:
        return 'Sight right: >1.2'   

def sightl_cat(d):
    if d >= 0.1 and d <= 0.7:
        return 'Sight left: 0.1-0.7'
    elif d >= 0.71 and d <= 1.0:
        return 'Sight left: 0.71-1.0'
    elif d >= 1.1 and d <= 1.2:
        return 'Sight left: 1.1-1.2'
    else:
        return 'Sight left: >1.2'   
    
    
def sbp_cat(d):
    if d >= 67 and d <= 112:
        return 'SBP: 67-112'
    elif d >= 68 and d <= 120:
        return 'SBP: 68-120'
    elif d >= 121 and d <= 131:
        return 'SBP: 121-131'
    else:
        return 'SBP: >132'   

def dbp_cat(d):
    if d >= 32 and d <= 70:
        return 'DBP: 32-70'
    elif d >= 71 and d <= 76:
        return 'DBP: 71-766'
    elif d >= 77 and d <= 82:
        return 'DBP: 77-82'
    else:
        return 'DBP: >83'
    
def hdl_cat(d):
    if d >= 1 and d <= 46:
        return '1-46'
    elif d >= 47 and d <= 55:
        return '47-55'
    elif d >= 56 and d <= 66:
        return '56-66'
    else:
        return '>67' 
    
def ldl_cat(d):
    if d >= 1 and d <= 89:
        return 'HDL: 1-89'
    elif d >= 90 and d <= 111:
        return 'HDL: 90-111'
    elif d >= 112 and d <= 135:
        return 'HDL: 112-135'
    else:
        return 'HDL: >136' 
    
def tri_cat(d):
    if d >= 1 and d <= 73:
        return 'Tri: 1-73'
    elif d >= 74 and d <= 106:
        return 'Tri: 74-106'
    elif d >= 107 and d <= 159:
        return 'Tri: 107-159'
    else:
        return 'Tri: >160' 
    
def hemo_cat(d):
    if d >= 1 and d <= 13.2:
        return 'hemo: 1-13.2'
    elif d >= 13.3 and d <= 14.3:
        return 'hemo: 13.3-14.3'
    elif d >= 14.4 and d <= 15.4:
        return 'hemo: 14.4-15.4'
    else:
        return 'hemo: >15.5' 
    
def urine_cat(d):
    if d == 6:
        return 'Urine: 6'
    else:
        return 'Urine: < 6'
    
def serum_cat(d):
    if d >= 0.1 and d <= 0.7:
        return 'Serum: 0.1-0.7'
    elif d >= 0.71 and d <= 0.8:
        return 'Serum: 0.71-0.8'
    elif d >= 0.81 and d <= 1.0:
        return 'Serum: 0.81-1.0'
    else:
        return 'Serum: >1.1' 
    
def ast_cat(d):
    if d >= 1 and d <= 19:
        return 'Ast: 1-19'
    elif d >= 20 and d <= 23:
        return 'Ast: 20-23'
    elif d >= 24 and d <= 28:
        return 'Ast: 24-28'
    else:
        return 'Ast: >29' 
    
def alt_cat(d):
    if d >= 1 and d <= 15:
        return 'Alt: 1-15'
    elif d >= 16 and d <= 20:
        return 'Alt: 16-20'
    elif d >= 21 and d <= 29:
        return 'Alt: 21-29'
    else:
        return 'Alt: >30'
    
def gamma_cat(d):
    if d >= 1 and d <= 16:
        return 'Gamma: 1-16'
    elif d >= 17 and d <= 23:
        return 'Gamma: 17-123'
    elif d >= 24 and d <= 39:
        return 'Gamma: 24-39'
    else:
        return 'Gamma: >40' 
    
def blds_cat(d):
    if d >= 25 and d <= 88:
        return 'Blds: 25-88'
    elif d >= 89 and d <= 96:
        return 'Blds: 89-96'
    elif d >= 97 and d <= 105:
        return 'Blds: 97-105'
    else:
        return 'Blds: >106' 
    
def tot_cat(d):
    if d >= 30 and d <= 169:
        return 'Tot: 30-169'
    elif d >= 170 and d <= 193:
        return 'Tot: 170-193'
    elif d >= 194 and d <= 219:
        return 'Tot: 194-219'
    else:
        return 'Tot: >220'

# %%
print('df shape:', df.shape)
print(df.describe())
# Out:
# df shape: (991346, 24)
#                  age         height         weight      waistline  \
# count  991346.000000  991346.000000  991346.000000  991346.000000
# mean       47.614491     162.240625      63.284050      81.233358
# std        14.181339       9.282957      12.514241      11.850323
# min        20.000000     130.000000      25.000000       8.000000
# 25%        35.000000     155.000000      55.000000      74.100000
# 50%        45.000000     160.000000      60.000000      81.000000
# 75%        60.000000     170.000000      70.000000      87.800000
# max        85.000000     190.000000     140.000000     999.000000
#
#           sight_left    sight_right      hear_left     hear_right  \
# count  991346.000000  991346.000000  991346.000000  991346.000000
# mean        0.980834       0.978429       1.031495       1.030476
# std         0.605949       0.604774       0.174650       0.171892
# min         0.100000       0.100000       1.000000       1.000000
# ...

# %%
data = []
for i in tqdm(range(len(df))):
    d = [df.at[i,'sex'], age_cat(df.at[i, 'age']), height_cat(df.at[i, 'height']),
         weight_cat(df.at[i, 'weight']), waistline_cat(df.at[i, 'waistline']), sightl_cat(df.at[i, 'sight_left']), 
         sightr_cat(df.at[i, 'sight_right']), 'hear left'+str(df.at[i, 'hear_left']), 'hear right'+str(df.at[i, 'hear_right']),
         sbp_cat(df.at[i, 'SBP']), dbp_cat(df.at[i, 'DBP']), blds_cat(df.at[i, 'BLDS']), tot_cat(df.at[i, 'tot_chole']), hdl_cat(df.at[i, 'HDL_chole']),
         ldl_cat(df.at[i, 'LDL_chole']), tri_cat(df.at[i, 'triglyceride']), hemo_cat(df.at[i, 'hemoglobin']),
         urine_cat(df.at[i, 'urine_protein']), serum_cat(df.at[i, 'serum_creatinine']),
         ast_cat(df.at[i, 'SGOT_AST']), alt_cat(df.at[i, 'SGOT_ALT']), gamma_cat(df.at[i, 'gamma_GTP']),
         'smk'+str(df.at[i, 'SMK_stat_type_cd']), 'drk'+df.at[i, 'DRK_YN']]
    data.append(d)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 991346/991346 [01:13<00:00, 13523.59it/s]

# %%
new_df = pd.DataFrame(data, columns=list(df.columns))
new_df.head()
# Out:
#     sex         age           height          weight         waistline  \
# 0  Male  AGE: 20-35  Height: 161-170  Weight: 71-140    Waistline: >88
# 1  Male  AGE: 20-35  Height: 171-190  Weight: 71-140    Waistline: >88
# 2  Male  AGE: 36-45  Height: 161-170  Weight: 71-140    Waistline: >88
# 3  Male  AGE: 46-60  Height: 171-190  Weight: 71-140    Waistline: >88
# 4  Male  AGE: 46-60  Height: 161-170   Weight: 56-60  Waistline: 76-81
#
#              sight_left            sight_right     hear_left     hear_right  \
# 0  Sight left: 0.71-1.0  Sight right: 0.71-1.0  hear left1.0  hear right1.0
# 1  Sight left: 0.71-1.0   Sight right: 1.1-1.2  hear left1.0  hear right1.0
# 2   Sight left: 1.1-1.2      Sight right: >1.2  hear left1.0  hear right1.0
# 3      Sight left: >1.2   Sight right: 1.1-1.2  hear left1.0  hear right1.0
# 4  Sight left: 0.71-1.0   Sight right: 1.1-1.2  hear left1.0  hear right1.0
#
#             SBP  ...     LDL_chole  triglyceride       hemoglobin  \
# ...

# %%
data
# Out:
# [['Male',
#   'AGE: 20-35',
#   'Height: 161-170',
#   'Weight: 71-140',
#   'Waistline: >88',
#   'Sight left: 0.71-1.0',
#   'Sight right: 0.71-1.0',
#   'hear left1.0',
#   'hear right1.0',
#   'SBP: 68-120',
#   'DBP: 77-82',
#   'Blds: 97-105',
#   'Tot: 170-193',
#   '47-55',
#   'HDL: 112-135',
#   'Tri: 74-106',
#   'hemo: >15.5',
#   'Urine: < 6',
#   'Serum: 0.81-1.0',
#   'Ast: 20-23',
#   'Alt: >30',
#   'Gamma: >40',
#   'smk1.0',
#   'drkY'],
#  ['Male',
#   'AGE: 20-35',
#   'Height: 171-190',
#   'Weight: 71-140',
#   'Waistline: >88',
#   'Sight left: 0.71-1.0',
#   'Sight right: 1.1-1.2',
#   'hear left1.0',
#   'hear right1.0',
#   'SBP: 121-131',
#   'DBP: 77-82',
#   'Blds: >106',
#   'Tot: >220',
#   '47-55',
#   'HDL: >136',
#   'Tri: 107-159',
#   'hemo: >15.5',
#   'Urine: < 6',
#   'Serum: 0.81-1.0',
#   'Ast: 20-23',
#   'Alt: >30',
#   'Gamma: 24-39',
#   'smk3.0',
#   'drkN'],
#  ['Male',
#   'AGE: 36-45',
#   'Height: 161-170',
#   'Weight: 71-140',
# ...

# %%
from apyori import apriori

# %%
rules1 = apriori(data, min_support=0.15)

# %%
rule1 = list(rules1)

# %%
rules2 = apriori(data, min_support=0.05)

# %%
rule2 = list(rules2)

# %%
result = {}
for i in rule1:
    items = [j for j in i[0]]
    output = 'Rule: '
    for ii in range(len(items)):
        output += str(items[ii]) + ' -> '
    result[output[:-4]] = i[1]
    #print(output[:-4])
    #print('Support:' + str(i[1]))
    #print('-------------------------------')

# %%
new = sorted(result.items(), key=lambda x:x[1], reverse=True)
for i in new:
    if ('drkY' in i[0] or 'smk3.0' in i[0]) and 'hear' not in i[0] and 'Urine' not in i[0]: 
        print(i)
# Out:
# ('Rule: drkY', 0.49981338503408496)
# ('Rule: drkY -> Male', 0.3574100263681903)
# ('Rule: drkY -> Height: 161-170', 0.22380581552757564)
# ('Rule: smk3.0', 0.2158217211750489)
# ('Rule: drkY -> smk1.0', 0.21529415562275936)
# ('Rule: Sight right: 0.71-1.0 -> drkY', 0.205316811688351)
# ('Rule: drkY -> Sight left: 0.71-1.0', 0.20425663693604454)
# ('Rule: drkY -> Height: 161-170 -> Male', 0.19957512311544104)
# ('Rule: Male -> smk3.0', 0.19943188351998192)
# ('Rule: drkY -> Serum: 0.81-1.0', 0.19092022361516564)
# ('Rule: drkY -> Gamma: >40', 0.17998559534209044)
# ('Rule: drkY -> Serum: 0.81-1.0 -> Male', 0.17089694213725581)
# ('Rule: drkY -> hemo: >15.5', 0.16682470096212623)
# ('Rule: drkY -> AGE: 20-35', 0.16636371155983884)
# ('Rule: hemo: >15.5 -> drkY -> Male', 0.1654165145166269)
# ('Rule: drkY -> Male -> Gamma: >40', 0.16422823111204363)
# ('Rule: drkY -> smk3.0', 0.16298749377109506)
# ('Rule: drkY -> Weight: 61-70', 0.15338539722760772)
# ...
